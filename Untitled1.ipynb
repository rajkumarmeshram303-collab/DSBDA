# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\RAJKUMAR\Music\custom_data.csv")

# %%
df.head()
# Out:
#    math_score   reading_score   writing_score   clubing  placement_score  \
# 0        81.0              84               70   2024.0             86.0
# 1        68.0              85               76   2020.0             94.0
# 2        83.0              75               64   2024.0             75.0
# 3        76.0              84               73   2024.0             89.0
# 4         NaN              91               76   2024.0             81.0
#
#    placement_offer
# 0                3
# 1                2
# 2                2
# 3                2
# 4                3

# %%
df.isnull().sum()
# Out:
# math_score         3
#  reading_score     0
#  writing_score     0
# clubing            3
# placement_score    5
# placement_offer    0
# dtype: int64

# %%
df['math_score'] = df['math_score'].fillna(df['math_score'].mean())

# %%
df.isnull().sum()
# Out:
# math_score         0
#  reading_score     0
#  writing_score     0
# clubing            3
# placement_score    5
# placement_offer    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# math_score         0
#  reading_score     0
#  writing_score     0
# clubing            0
# placement_score    5
# placement_offer    0
# dtype: int64

# %%
df['clubing'] = df['clubing'].fillna(df['clubing'].min())

# %%
df['placement_score'] = df['placement_score'].fillna(df['placement_score'].min())

# %%
df.isnull().sum()
# Out:
# math_score         0
#  reading_score     0
#  writing_score     0
# clubing            0
# placement_score    0
# placement_offer    0
# dtype: int64

# %%
df.describe()
# Out:
#        math_score   reading_score   writing_score       clubing  \
# count   99.000000       99.000000        99.000000    99.000000
# mean    75.864583       84.707071        69.868687  2022.070707
# std     11.337692        6.089892         5.889538     1.430374
# min      0.000000       75.000000        60.000000  2020.000000
# 25%     69.500000       80.000000        65.000000  2021.000000
# 50%     77.000000       85.000000        69.000000  2022.000000
# 75%     83.000000       90.000000        75.500000  2023.000000
# max     90.000000       95.000000        80.000000  2024.000000
#
#        placement_score  placement_offer
# count        99.000000        99.000000
# mean         86.515152         2.464646
# std           7.985144         0.501287
# min          75.000000         2.000000
# 25%          79.000000         2.000000
# 50%          87.000000         2.000000
# 75%          94.000000         3.000000
# max         100.000000         3.000000

# %%
df.mean(numeric_only=True)
# Out:
# math_score           75.864583
#  reading_score       84.707071
#  writing_score       69.868687
# clubing            2022.070707
# placement_score      86.515152
# placement_offer       2.464646
# dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# math_score            0.0
#  reading_score       75.0
#  writing_score       60.0
# clubing            2020.0
# placement_score      75.0
# placement_offer       2.0
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# math_score           90.0
#  reading_score       95.0
#  writing_score       80.0
# clubing            2024.0
# placement_score     100.0
# placement_offer       3.0
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# math_score         11.337692
#  reading_score      6.089892
#  writing_score      5.889538
# clubing             1.430374
# placement_score     7.985144
# placement_offer     0.501287
# dtype: float64
